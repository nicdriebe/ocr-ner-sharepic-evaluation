# %% [markdown]
# ### Eintragung des extrahierten Textes von ChatGPT in CSV Datei
#
# * die CSV Datei wurde im Verlauf der Arbeit umbenannt und im Projektverzeichnis verschoben. Die hier aufgerufenen csv Datein sind nicht merh Teil des Projekts, aber warne die gRndlage für die finale Datei "images_data_with_groundtruth.csv

# %%
import pandas as pd
import os
import csv

df = pd.read_csv("sharepics.csv")  
df.head()
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
#                                        original name  new name    category  \
# 0  Weihnachtsfeier im Sprachcafé! Wir laden euch ...  0001.jpg  background
# 1  Dresden 8.8. 16 Uhr #demokratischerwiderstand ...  0002.jpg  background
# 2  kein vergeben – kein vergessen- gedenken heißt...  0003.jpg  background
# 3  Am Mittwoch singen wir wieder gemeinsam! Diesm...  0004.jpg  background
# 4  das ---amt blank empfiehlt-demo gegen gentrifi...  0006.jpg  background
#
#                                                  URL  Plattform  \
# 0  https://www.instagram.com/p/CXTzhTAs4O2/?img_i...  Instagram
# 1           https://www.instagram.com/p/CDbyO8SnQ9Z/  Instagram
# 2           https://www.instagram.com/p/CzRO0TuqUEN/  Instagram
# 3           https://www.instagram.com/p/Ctqhn4Ct99Z/  Instagram
# ...

# %%
# Zwei neue leere Spalten hinzufügen
df['text'] = ''
df['OCR_ChatGPT4'] = ''

# %%
df.head()
# Out:
#                                        original name  new name    category  \
# 0  Weihnachtsfeier im Sprachcafé! Wir laden euch ...  0001.jpg  background
# 1  Dresden 8.8. 16 Uhr #demokratischerwiderstand ...  0002.jpg  background
# 2  kein vergeben – kein vergessen- gedenken heißt...  0003.jpg  background
# 3  Am Mittwoch singen wir wieder gemeinsam! Diesm...  0004.jpg  background
# 4  das ---amt blank empfiehlt-demo gegen gentrifi...  0006.jpg  background
#
#                                                  URL  Plattform  \
# 0  https://www.instagram.com/p/CXTzhTAs4O2/?img_i...  Instagram
# 1           https://www.instagram.com/p/CDbyO8SnQ9Z/  Instagram
# 2           https://www.instagram.com/p/CzRO0TuqUEN/  Instagram
# 3           https://www.instagram.com/p/Ctqhn4Ct99Z/  Instagram
# 4           https://www.instagram.com/p/CfwC9xjKdM4/  Instagram
#
#          channel name text OCR_ChatGPT4
# 0   sprachcafe.berlin
# 1        nichtohneuns
# 2  about.blank.berlin
# ...

# %%
df.to_csv("sharepics.csv", index=False)

# %%
df = pd.read_csv("sharepics.csv")  
df.head()
# Out:
#                                        original name  new name    category  \
# 0  Weihnachtsfeier im Sprachcafé! Wir laden euch ...  0001.jpg  background
# 1  Dresden 8.8. 16 Uhr #demokratischerwiderstand ...  0002.jpg  background
# 2  kein vergeben – kein vergessen- gedenken heißt...  0003.jpg  background
# 3  Am Mittwoch singen wir wieder gemeinsam! Diesm...  0004.jpg  background
# 4  das ---amt blank empfiehlt-demo gegen gentrifi...  0006.jpg  background
#
#                                                  URL  Plattform  \
# 0  https://www.instagram.com/p/CXTzhTAs4O2/?img_i...  Instagram
# 1           https://www.instagram.com/p/CDbyO8SnQ9Z/  Instagram
# 2           https://www.instagram.com/p/CzRO0TuqUEN/  Instagram
# 3           https://www.instagram.com/p/Ctqhn4Ct99Z/  Instagram
# 4           https://www.instagram.com/p/CfwC9xjKdM4/  Instagram
#
#          channel name  text  OCR_ChatGPT4
# 0   sprachcafe.berlin   NaN           NaN
# 1        nichtohneuns   NaN           NaN
# ...

# %%
df['OCR_ChatGPT4'] = df['OCR_ChatGPT4'].astype(str)
df['text'] = df['text'].astype(str)

# %%
df = pd.read_csv("sharepics.csv")

# %%
df.head(6)
# Out:
#                                        original name  new name    category  \
# 0  Weihnachtsfeier im Sprachcafé! Wir laden euch ...  0001.jpg  background
# 1  Dresden 8.8. 16 Uhr #demokratischerwiderstand ...  0002.jpg  background
# 2  kein vergeben – kein vergessen- gedenken heißt...  0003.jpg  background
# 3  Am Mittwoch singen wir wieder gemeinsam! Diesm...  0004.jpg  background
# 4  das ---amt blank empfiehlt-demo gegen gentrifi...  0006.jpg  background
# 5  die @f_antifa_9._mai ruf wie jedes jahr zum ta...  0007.jpg  background
#
#                                                  URL  Plattform  \
# 0  https://www.instagram.com/p/CXTzhTAs4O2/?img_i...  Instagram
# 1           https://www.instagram.com/p/CDbyO8SnQ9Z/  Instagram
# 2           https://www.instagram.com/p/CzRO0TuqUEN/  Instagram
# 3           https://www.instagram.com/p/Ctqhn4Ct99Z/  Instagram
# 4           https://www.instagram.com/p/CfwC9xjKdM4/  Instagram
# ...

# %%
df.loc[df['new name'] == '0034.jpg', 'OCR_ChatGPT4'] = 'FREIHEIT GLEICHHEIT SOLIDARNOŚĆ BERLIN GLOBAL QUEER, REBEL, SOVIET A STORY ABOUT POLAND'S FIRST GLAM ROCKER The Rise & Fall of Zygmunt Blask Film premiere 11.09.2024 6:30 PM 5 € / 3 € reduced'
# Out:
#   Cell In[109], line 1
#     df.loc[df['new name'] == '0034.jpg', 'OCR_ChatGPT4'] = 'FREIHEIT GLEICHHEIT SOLIDARNOŚĆ BERLIN GLOBAL QUEER, REBEL, SOVIET A STORY ABOUT POLAND'S FIRST GLAM ROCKER The Rise & Fall of Zygmunt Blask Film premiere 11.09.2024 6:30 PM 5 € / 3 € reduced'
#                                                                                                                                                                                                                                             ^
# SyntaxError: invalid character '€' (U+20AC)

# %%
print(df.loc[df['new name'] == '0001.jpg', 'OCR_ChatGPT4'].values)
# Out:
# [nan]

# %%
df.to_csv("sharepics.csv", index=False, encoding='utf-8')
