# %% [markdown]
# # Gemma 2 Evaluation - 01 -
#
# In diesem notebook wird untersucht wie gut Gemma 2 die gewünschten Entitäten (EVENT, TOPIC, DATE, TIME, LOC) erkennt.
#
# Es wird folgendes Model genutzt: **"gemma-2-2b-it"**
# kleinstes Modell der Gemma2 Modelle
# (2B model was trained with 2 trillion tokens)
#
# Die Performance von Gemma 2 wird auf dem Ground Truth untersucht.
#
# **erste Quantitative Analyse - Berechnung von Precision, Recall und F1-Score - nur als erster Vergleich zw den unterschiedlichen Prompts**
#
# --> es werden zwei Durchläufe mit demselben Prompt durchgeführt

# %% [markdown]
# ----
#
# **Prompt:**
#
# prompt = f"""
#         Der folgende Text wurde aus einem Plakat extrahiert.
#         Bitte extrahiere die folgenden **Kategorien**, wenn möglich:
#
#         1. **Ort** (z. B. Straßen mit Hausnummern, Plätze, Gebäude, Stadtteile, Städte)
#         2. **Datum** (z. B. "21.12.", "Dienstag", "9. November", "8.8. 2021")
#         3. **Zeit** (z. B. "19 Uhr", "18:00 Uhr")
#         4. **Kategorie der Veranstaltung** (z. B. "Kundgebung", "Weihnachtsfeier", "Demonstration")
#         5. **Thema der Veranstaltung** (z. B. "Solidarität mit ...", "Gedenken an...", "für Frieden")
#
#         Beachte unbedingt:
#         - Gib nur Kategorien aus, bei denen du sicher bist, dass sie stimmen.
#         - Nimm nur Wörter, die im Text vorkommen.
#         - Es sind nicht unbedingt alle Kategorien im Text zu finden.
#         - Kategorien können mehrfach vorhanden sein.
#
#         Gib das Ergebnis bitte als **strukturierte Liste** im folgenden JSON-Format aus:
#
#         ```json
#         {{
#         "Ort": [...],
#         "Datum": [...],
#         "Zeit": [...],
#         "Kategorie": [...],
#         "Thema": [...]
#         }}
#
#         Hier ist der Text:
#         {text}

# %% [markdown]
# **---> es wurden zwei Durchläufe mit demselben Prompt gemacht**

# %% [markdown]
# ---

# %%
from huggingface_hub import login
import os

login(token=os.getenv("HUGGINGFACE_TOKEN"))
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !pip install transformers torch accelerate
# Out:
# Requirement already satisfied: transformers in /Users/blongsch/ikt/lib/python3.11/site-packages (4.53.2)
# Requirement already satisfied: torch in /Users/blongsch/ikt/lib/python3.11/site-packages (2.1.0)
# Requirement already satisfied: accelerate in /Users/blongsch/ikt/lib/python3.11/site-packages (1.7.0)
# Requirement already satisfied: filelock in /Users/blongsch/ikt/lib/python3.11/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /Users/blongsch/ikt/lib/python3.11/site-packages (from transformers) (0.33.0)
# Requirement already satisfied: numpy>=1.17 in /Users/blongsch/ikt/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/blongsch/ikt/lib/python3.11/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/blongsch/ikt/lib/python3.11/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/blongsch/ikt/lib/python3.11/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /Users/blongsch/ikt/lib/python3.11/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/blongsch/ikt/lib/python3.11/site-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/blongsch/ikt/lib/python3.11/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/blongsch/ikt/lib/python3.11/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/blongsch/ikt/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/blongsch/ikt/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.12.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/blongsch/ikt/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.3)
# Requirement already satisfied: sympy in /Users/blongsch/ikt/lib/python3.11/site-packages (from torch) (1.13.1)
# Requirement already satisfied: networkx in /Users/blongsch/ikt/lib/python3.11/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /Users/blongsch/ikt/lib/python3.11/site-packages (from torch) (3.1.4)
# Requirement already satisfied: psutil in /Users/blongsch/ikt/lib/python3.11/site-packages (from accelerate) (6.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/blongsch/ikt/lib/python3.11/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/blongsch/ikt/lib/python3.11/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/blongsch/ikt/lib/python3.11/site-packages (from requests->transformers) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/blongsch/ikt/lib/python3.11/site-packages (from requests->transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/blongsch/ikt/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/blongsch/ikt/lib/python3.11/site-packages (from sympy->torch) (1.3.0)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
model_name = "google/gemma-2b-it"
tokenizer = AutoTokenizer.from_pretrained(model_name)
#model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16, device_map="cpu") #habe kein gpu, deshab cpu
model = AutoModelForCausalLM.from_pretrained(model_name, device_map="cpu")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ---

# %% [markdown]
# ### Auf Datensatz iterieren und Output im Json-Format speichern

# %%
# Funktion extract_entities
import json
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline


# Model und Pipeline
model_name = "google/gemma-2b-it"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
generator = pipeline("text-generation", model=model, tokenizer=tokenizer, device=-1)

def extract_entities(data):
    results = []

    for eintrag in data:
        file_name = eintrag["file_name"]
        text = eintrag["text"]
    
        prompt = f"""
        Der folgende Text wurde aus einem Plakat extrahiert.
        Bitte extrahiere die folgenden **Kategorien**, wenn möglich:
        
        1. **Ort** (z. B. Straßen mit Hausnummern, Plätze, Gebäude, Stadtteile, Städte)
        2. **Datum** (z. B. "21.12.", "Dienstag", "9. November", "8.8. 2021")
        3. **Zeit** (z. B. "19 Uhr", "18:00 Uhr")
        4. **Kategorie der Veranstaltung** (z. B. "Kundgebung", "Weihnachtsfeier", "Demonstration")
        5. **Thema der Veranstaltung** (z. B. "Solidarität mit ...", "Gedenken an...", "für Frieden")
        
        Beachte unbedingt: 
        - Gib nur Kategorien aus, bei denen du sicher bist, dass sie stimmen.
        - Nimm nur Wörter, die im Text vorkommen. 
        - Es sind nicht unbedingt alle Kategorien im Text zu finden.
        - Kategorien können mehrfach vorhanden sein.
        
        Gib das Ergebnis bitte als **strukturierte Liste** im folgenden JSON-Format aus:
        
        ```json
        {{
        "Ort": [...],
        "Datum": [...],
        "Zeit": [...],
        "Kategorie": [...],
        "Thema": [...]
        }}
        
        Hier ist der Text:
        {text}
        """
        
        try:
            output = generator(prompt, max_new_tokens=400)[0]["generated_text"]
            extracted_json = output.split("```json")[-1].split("```")[0].strip()  # nur Output nach "```json" wird genommen
            extracted = json.loads(extracted_json)
        
            results.append({
                "file_name": file_name,
                "entities": extracted
            })
        
        except Exception as e:
            print(f"Fehler bei {file_name}: {e}")
            results.append({
                "file_name": file_name,
                "entities": None,
                "error": str(e)
            })
        
    return results
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cpu

# %%
import sys
import os
import json
#sys.path.append(os.path.abspath(".."))
#from ressourcen_monitor import monitor

with open("../../data/data_annotated.json", encoding="utf-8") as f:
    data = json.load(f)

#@monitor(full_name="Gemma2 Prompt1_2 NER")
#def run_ner():
#    return extract_entities(data)
#results = run_ner()

results = extract_entities(data)

with open("../../data/NER/gemma2/prompt1/gemma2_entity_output_prompt1_2.json", "w", encoding="utf-8") as f:
    json.dump(results, f, ensure_ascii=False, indent=2)
# Out:
# Fehler bei 0002.jpg: Expecting ',' delimiter: line 16 column 1 (char 181)
# Fehler bei 0009.jpg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0025.jpg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0027.jpg: Expecting ',' delimiter: line 15 column 61 (char 223)
# Fehler bei 0035.jpg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0044.jpg: Expecting ',' delimiter: line 7 column 1 (char 166)
# Fehler bei 0062.jpg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0064.jpg: Expecting property name enclosed in double quotes: line 7 column 1 (char 129)
# Fehler bei 0093.jpg: Expecting ',' delimiter: line 13 column 1 (char 520)
# Fehler bei 0103.jpg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0111.jpg: Expecting ',' delimiter: line 7 column 1 (char 114)
# Fehler bei 0112.jpg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0118.jpeg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0119.jpeg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0121.jpg: Expecting ',' delimiter: line 7 column 1 (char 145)
# Fehler bei 0124.jpg: Expecting ',' delimiter: line 7 column 1 (char 128)
# Fehler bei 0140.jpg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0143.jpg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0145.jpg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0146.jpg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0158.jpg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0162.jpeg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0165.jpg: Expecting ',' delimiter: line 7 column 1 (char 126)
# Fehler bei 0170.jpeg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0172.jpg: Expecting ',' delimiter: line 7 column 1 (char 157)
# Fehler bei 0181.jpg: Expecting ',' delimiter: line 7 column 1 (char 166)
# Fehler bei 0198.jpg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0201.jpg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0204.jpg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0205.jpg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0209.jpg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0210.jpg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0214.jpg: Expecting ',' delimiter: line 7 column 1 (char 132)
# Fehler bei 0215.jpg: Expecting ',' delimiter: line 7 column 1 (char 124)
# Fehler bei 0218.jpg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0225.jpg: Expecting ',' delimiter: line 7 column 1 (char 149)
# Fehler bei 0235.jpg: Expecting ',' delimiter: line 7 column 1 (char 158)
# Fehler bei 0239.jpg: Expecting ',' delimiter: line 7 column 1 (char 114)
# Fehler bei 0241.jpg: Expecting value: line 2 column 17 (char 18)
# Fehler bei 0242.jpg: Expecting ',' delimiter: line 7 column 1 (char 122)

# %% [markdown]
# ### Json-Datei bereinigen

# %%
# auf "leere"/ ungültige Einträge prüfen
import json

# JSON laden
with open("../../data/NER/gemma2/prompt1/gemma2_entity_output_prompt1_2.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Zähler initialisieren
gesamt = len(data)
ungueltig = 0
mit_error = 0
gueltig = 0

for eintrag in data:
    entities = eintrag.get("entities")
    
    if not entities or not isinstance(entities, dict):
        ungueltig += 1
        if "error" in eintrag:
            mit_error += 1
    else:
        gueltig += 1

# Ausgabe
print(f"Gesamtanzahl Dateien: {gesamt}")
print(f"Ungültige Einträge (keine Entities oder kaputt): {ungueltig}")
print(f"  └── davon mit 'error'-Feld: {mit_error}")
print(f"Gültige Einträge (Entities vorhanden): {gueltig}")
# Out:
# Gesamtanzahl Dateien: 200
# Ungültige Einträge (keine Entities oder kaputt): 40
#   └── davon mit 'error'-Feld: 40
# Gültige Einträge (Entities vorhanden): 160

# %%
# Datei bereingigen & Labels mappen
import json

# Label-Mapping
label_map = {
    "Ort": "LOC",
    "Datum": "DATE",
    "Zeit": "TIME",
    "Kategorie": "EVENT",
    "Thema": "TOPIC"
}

# JSON laden
with open("../../data/NER/gemma2/prompt1/gemma2_entity_output_prompt1_2.json", "r", encoding="utf-8") as f:
    data = json.load(f)

bereinigt = []
for eintrag in data:
    entities = eintrag.get("entities")

    if not entities or not isinstance(entities, dict):
        continue  # überspringen, wenn kaputt oder leer
    
    # null-Werte rausfiltern und Keys mappen
    entities_cleaned = {
        label_map.get(k, k): v
        for k, v in entities.items()
        if v is not None
    }

    # überspringen, wenn nach dem Filtern nichts übrig ist (optional)
    if not entities_cleaned:
        continue

    eintrag["entities"] = entities_cleaned
    bereinigt.append(eintrag)

# Speichern
with open("../../data/NER/gemma2/prompt1/gemma2_entity_output_prompt1_2_cleaned.json", "w", encoding="utf-8") as f:
    json.dump(bereinigt, f, ensure_ascii=False, indent=2)

# %%
# Json in Struktur des Goldstandard umwandeln

import json

# Datei laden
with open("../../data/NER/gemma2/prompt1/gemma2_entity_output_prompt1_2_cleaned.json", encoding="utf-8") as f:
    gemma_data = json.load(f)

# Normalisieren
def normalize_to_list(value):
    if isinstance(value, list):
        return [v.strip() for v in value if isinstance(v, str) and v.strip()]
    elif isinstance(value, str) and value.strip():
        return [value.strip()]
    else:
        return []

# In Goldstandard-ähnliche Struktur bringen
converted = []

for entry in gemma_data:
    file_name = entry.get("file_name")
    raw_entities = entry.get("entities", {})
    
    entities = []
    for label, value in raw_entities.items():
        values = normalize_to_list(value)
        for v in values:
            entities.append({
                "label": label,
                "text": v
            })
    
    converted.append({
        "file_name": file_name,
        "entities": entities
    })

# Speichern
with open("../../data/NER/gemma2/prompt1/gemma2_prompt1_2_as_goldstructure.json", "w", encoding="utf-8") as f:
    json.dump(converted, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ### Evaluation - 1. Durchlauf

# %%
# auf "leere"/ ungültige Einträge prüfen
import json

# JSON laden
with open("../../data/NER/gemma2/prompt1/gemma2_entity_output_prompt1_1_cleaned.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Zähler initialisieren
gesamt = len(data)
ungueltig = 0
mit_error = 0
gueltig = 0

for eintrag in data:
    entities = eintrag.get("entities")
    
    if not entities or not isinstance(entities, dict):
        ungueltig += 1
        if "error" in eintrag:
            mit_error += 1
    else:
        gueltig += 1

# Ausgabe
print(f"Gesamtanzahl Dateien: {gesamt}")
print(f"Ungültige Einträge (keine Entities oder kaputt): {ungueltig}")
print(f"  └── davon mit 'error'-Feld: {mit_error}")
print(f"Gültige Einträge (Entities vorhanden): {gueltig}")
# Out:
# Gesamtanzahl Dateien: 160
# Ungültige Einträge (keine Entities oder kaputt): 0
#   └── davon mit 'error'-Feld: 0
# Gültige Einträge (Entities vorhanden): 160

# %%
import json
from tqdm import tqdm
from collections import defaultdict
from sklearn.metrics import precision_recall_fscore_support
import pandas as pd

# === Dateien laden ===
with open("../../data/data_annotated.json", encoding="utf-8") as f:
    gold_data = json.load(f)

with open("../../data/NER/gemma2/prompt1/gemma2_prompt1_1_as_goldstructure.json", encoding="utf-8") as f:
    gemma_data = json.load(f)

# === Zu vergleichende Labels ===
label_names = ["LOC", "DATE", "TIME", "EVENT", "TOPIC"]

# === Entitäten extrahieren ===
def extract_entities(entry):
    ent_dict = {}
    for ent in entry.get("entities", []):
        label = ent.get("label")
        text = ent.get("text", "").strip()
        if label and text:
            ent_dict.setdefault(label, []).append(text)
    return ent_dict

# === Mapping der Vorhersagen für schnellen Zugriff ===
gemma_dict = {entry["file_name"]: entry for entry in gemma_data}

# === Vergleich vorbereiten ===
y_true_all = []
y_pred_all = []
y_true_per_label = defaultdict(list)
y_pred_per_label = defaultdict(list)

# === Vergleichsloop über alle Goldstandard-Dateien ===
for gold_entry in tqdm(gold_data):
    file_name = gold_entry["file_name"]
    gold_ents = extract_entities(gold_entry)
    pred_entry = gemma_dict.get(file_name)
    pred_ents = extract_entities(pred_entry) if pred_entry else {}

    for label in label_names:
        gold_texts = set(t.strip() for t in gold_ents.get(label, []) if isinstance(t, str))
        val = pred_ents.get(label)

        if isinstance(val, list):
            pred_texts = set(t.strip() for t in val if isinstance(t, str))
        elif isinstance(val, str):
            pred_texts = {val.strip()}
        else:
            pred_texts = set()

        for text in gold_texts:
            if text in pred_texts:
                y_true_all.append(1)
                y_pred_all.append(1)
                y_true_per_label[label].append(1)
                y_pred_per_label[label].append(1)
                pred_texts.remove(text)
            else:
                y_true_all.append(1)
                y_pred_all.append(0)
                y_true_per_label[label].append(1)
                y_pred_per_label[label].append(0)

        for text in pred_texts:
            y_true_all.append(0)
            y_pred_all.append(1)
            y_true_per_label[label].append(0)
            y_pred_per_label[label].append(1)

# === Gesamtmetriken ===
precision, recall, f1, _ = precision_recall_fscore_support(
    y_true_all, y_pred_all, average="binary", zero_division=0
)

print("\n🔍 Gesamtergebnis (alle Goldstandard-Dateien)")
print(f"Precision: {precision:.3f}")
print(f"Recall:    {recall:.3f}")
print(f"F1-Score:  {f1:.3f}")

# === Pro-Label-Metriken ===
rows = []
for label in label_names:
    y_true = y_true_per_label[label]
    y_pred = y_pred_per_label[label]

    if not y_true and not y_pred:
        precision = recall = f1 = 0.0
    else:
        precision, recall, f1, _ = precision_recall_fscore_support(
            y_true, y_pred, average="binary", zero_division=0
        )

    rows.append({
        "Label": label,
        "Precision": round(precision, 3),
        "Recall": round(recall, 3),
        "F1-Score": round(f1, 3),
        "Anzahl in Gold": sum(y_true),
        "Anzahl Predicted": sum(y_pred)
    })

# Ausgabe
df_metrics = pd.DataFrame(rows).sort_values("Label")
print("\n📊 Metriken pro Kategorie:")
print(df_metrics.to_string(index=False))
# Out:
# 100%|██████████████████████████████████████| 200/200 [00:00<00:00, 86766.74it/s]
# 🔍 Gesamtergebnis (alle Goldstandard-Dateien)
# Precision: 0.294
# Recall:    0.144
# F1-Score:  0.193
#
# 📊 Metriken pro Kategorie:
# Label  Precision  Recall  F1-Score  Anzahl in Gold  Anzahl Predicted
#  DATE      0.433   0.245     0.313             290               164
# EVENT      0.206   0.135     0.163             237               155
#   LOC      0.333   0.052     0.090             403                63
#  TIME      0.469   0.315     0.376             213               143
# TOPIC      0.063   0.039     0.048             255               158

# %% [markdown]
# --- > niedriger Wert - für nur 160 von 200 existierenden Files Vorhersagen getroffen - zieht Ergebnis u.a. runter

# %% [markdown]
# #### nur Dateien mit erkannten Entitäten in die Auswertung mit einbeziehen

# %%
import json
from tqdm import tqdm
from collections import defaultdict
from sklearn.metrics import precision_recall_fscore_support
import pandas as pd

# === Dateien laden ===
with open("../../data/data_annotated.json", encoding="utf-8") as f:
    gold_data = json.load(f)

with open("../../data/NER/gemma2/prompt1/gemma2_prompt1_1_as_goldstructure.json", encoding="utf-8") as f:
    gemma_data = json.load(f)

# === Zu vergleichende Labels ===
label_names = ["LOC", "DATE", "TIME", "EVENT", "TOPIC"]

# === Entitäten extrahieren ===
def extract_entities(entry):
    ent_dict = {}
    for ent in entry.get("entities", []):
        label = ent.get("label")
        text = ent.get("text", "").strip()
        if label and text:
            ent_dict.setdefault(label, []).append(text)
    return ent_dict

# === Gemeinsame Dateien filtern ===
gold_files = {entry["file_name"] for entry in gold_data}
gemma_files = {entry["file_name"] for entry in gemma_data}
common_files = gold_files & gemma_files

filtered_gold = [entry for entry in gold_data if entry["file_name"] in common_files]
gemma_dict = {entry["file_name"]: entry for entry in gemma_data if entry["file_name"] in common_files}

# === Vergleich vorbereiten ===
y_true_all = []
y_pred_all = []

# pro Label getrennte Zählung
y_true_per_label = defaultdict(list)
y_pred_per_label = defaultdict(list)

# === Vergleichsloop ===
for gold_entry in tqdm(filtered_gold):
    file_name = gold_entry["file_name"]
    gold_ents = extract_entities(gold_entry)
    pred_entry = gemma_dict.get(file_name)
    pred_ents = extract_entities(pred_entry) if pred_entry else {}

    for label in label_names:
        gold_texts = set(t.strip() for t in gold_ents.get(label, []) if isinstance(t, str))
        val = pred_ents.get(label)

        if isinstance(val, list):
            pred_texts = set(t.strip() for t in val if isinstance(t, str))
        elif isinstance(val, str):
            pred_texts = {val.strip()}
        else:
            pred_texts = set()

        # True Positives und False Negatives
        for text in gold_texts:
            if text in pred_texts:
                y_true_all.append(1)
                y_pred_all.append(1)
                y_true_per_label[label].append(1)
                y_pred_per_label[label].append(1)
                pred_texts.remove(text)
            else:
                y_true_all.append(1)
                y_pred_all.append(0)
                y_true_per_label[label].append(1)
                y_pred_per_label[label].append(0)

        # Verbleibende Vorhersagen = False Positives
        for text in pred_texts:
            y_true_all.append(0)
            y_pred_all.append(1)
            y_true_per_label[label].append(0)
            y_pred_per_label[label].append(1)

# === Gesamtmetriken ===
precision, recall, f1, _ = precision_recall_fscore_support(
    y_true_all, y_pred_all, average="binary", zero_division=0
)

print("\n🔍 Gesamtergebnis (nur gemeinsame Dateien)")
print(f"Precision: {precision:.3f}")
print(f"Recall:    {recall:.3f}")
print(f"F1-Score:  {f1:.3f}")

# === Metriken pro Label ===
rows = []
for label in label_names:
    y_true = y_true_per_label[label]
    y_pred = y_pred_per_label[label]

    if not y_true and not y_pred:
        precision = recall = f1 = 0.0
    else:
        precision, recall, f1, _ = precision_recall_fscore_support(
            y_true, y_pred, average="binary", zero_division=0
        )

    rows.append({
        "Label": label,
        "Precision": round(precision, 3),
        "Recall": round(recall, 3),
        "F1-Score": round(f1, 3),
        "Anzahl in Gold": sum(y_true),
        "Anzahl Predicted": sum(y_pred)
    })

# Ausgabe als Tabelle
df_metrics = pd.DataFrame(rows).sort_values("Label")
print("\n📊 Metriken pro Kategorie:")
print(df_metrics.to_string(index=False))
# Out:
# 100%|█████████████████████████████████████| 160/160 [00:00<00:00, 104775.74it/s]
# 🔍 Gesamtergebnis (nur gemeinsame Dateien)
# Precision: 0.294
# Recall:    0.180
# F1-Score:  0.223
#
# 📊 Metriken pro Kategorie:
# Label  Precision  Recall  F1-Score  Anzahl in Gold  Anzahl Predicted
#  DATE      0.433   0.307     0.359             231               164
# EVENT      0.206   0.170     0.187             188               155
#   LOC      0.333   0.066     0.110             319                63
#  TIME      0.469   0.383     0.421             175               143
# TOPIC      0.063   0.049     0.055             203               158

# %%
Ergebnis nur wenig besser

# %% [markdown]
# ---
# ### Evaluation - 2. Durchlauf

# %%
# auf "leere"/ ungültige Einträge prüfen
import json

# JSON laden
with open("../../data/NER/gemma2/prompt1/gemma2_entity_output_prompt1_2_cleaned.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Zähler initialisieren
gesamt = len(data)
ungueltig = 0
mit_error = 0
gueltig = 0

for eintrag in data:
    entities = eintrag.get("entities")
    
    if not entities or not isinstance(entities, dict):
        ungueltig += 1
        if "error" in eintrag:
            mit_error += 1
    else:
        gueltig += 1

# Ausgabe
print(f"Gesamtanzahl Dateien: {gesamt}")
print(f"Ungültige Einträge (keine Entities oder kaputt): {ungueltig}")
print(f"  └── davon mit 'error'-Feld: {mit_error}")
print(f"Gültige Einträge (Entities vorhanden): {gueltig}")
# Out:
# Gesamtanzahl Dateien: 160
# Ungültige Einträge (keine Entities oder kaputt): 0
#   └── davon mit 'error'-Feld: 0
# Gültige Einträge (Entities vorhanden): 160

# %%
import json
from tqdm import tqdm
from collections import defaultdict
from sklearn.metrics import precision_recall_fscore_support
import pandas as pd

# === Dateien laden ===
with open("../../data/data_annotated.json", encoding="utf-8") as f:
    gold_data = json.load(f)

with open("../../data/NER/gemma2/prompt1/gemma2_prompt1_2_as_goldstructure.json", encoding="utf-8") as f:
    gemma_data = json.load(f)

# === Zu vergleichende Labels ===
label_names = ["LOC", "DATE", "TIME", "EVENT", "TOPIC"]

# === Entitäten extrahieren ===
def extract_entities(entry):
    ent_dict = {}
    for ent in entry.get("entities", []):
        label = ent.get("label")
        text = ent.get("text", "").strip()
        if label and text:
            ent_dict.setdefault(label, []).append(text)
    return ent_dict

# === Mapping der Vorhersagen für schnellen Zugriff ===
gemma_dict = {entry["file_name"]: entry for entry in gemma_data}

# === Vergleich vorbereiten ===
y_true_all = []
y_pred_all = []
y_true_per_label = defaultdict(list)
y_pred_per_label = defaultdict(list)

# === Vergleichsloop über alle Goldstandard-Dateien ===
for gold_entry in tqdm(gold_data):
    file_name = gold_entry["file_name"]
    gold_ents = extract_entities(gold_entry)
    pred_entry = gemma_dict.get(file_name)
    pred_ents = extract_entities(pred_entry) if pred_entry else {}

    for label in label_names:
        gold_texts = set(t.strip() for t in gold_ents.get(label, []) if isinstance(t, str))
        val = pred_ents.get(label)

        if isinstance(val, list):
            pred_texts = set(t.strip() for t in val if isinstance(t, str))
        elif isinstance(val, str):
            pred_texts = {val.strip()}
        else:
            pred_texts = set()

        for text in gold_texts:
            if text in pred_texts:
                y_true_all.append(1)
                y_pred_all.append(1)
                y_true_per_label[label].append(1)
                y_pred_per_label[label].append(1)
                pred_texts.remove(text)
            else:
                y_true_all.append(1)
                y_pred_all.append(0)
                y_true_per_label[label].append(1)
                y_pred_per_label[label].append(0)

        for text in pred_texts:
            y_true_all.append(0)
            y_pred_all.append(1)
            y_true_per_label[label].append(0)
            y_pred_per_label[label].append(1)

# === Gesamtmetriken ===
precision, recall, f1, _ = precision_recall_fscore_support(
    y_true_all, y_pred_all, average="binary", zero_division=0
)

print("\n🔍 Gesamtergebnis 2. Durchlauf (alle Goldstandard-Dateien)")
print(f"Precision: {precision:.3f}")
print(f"Recall:    {recall:.3f}")
print(f"F1-Score:  {f1:.3f}")

# === Pro-Label-Metriken ===
rows = []
for label in label_names:
    y_true = y_true_per_label[label]
    y_pred = y_pred_per_label[label]

    if not y_true and not y_pred:
        precision = recall = f1 = 0.0
    else:
        precision, recall, f1, _ = precision_recall_fscore_support(
            y_true, y_pred, average="binary", zero_division=0
        )

    rows.append({
        "Label": label,
        "Precision": round(precision, 3),
        "Recall": round(recall, 3),
        "F1-Score": round(f1, 3),
        "Anzahl in Gold": sum(y_true),
        "Anzahl Predicted": sum(y_pred)
    })

# Ausgabe
df_metrics = pd.DataFrame(rows).sort_values("Label")
print("\n📊 Metriken pro Kategorie:")
print(df_metrics.to_string(index=False))
# Out:
# 100%|█████████████████████████████████████| 200/200 [00:00<00:00, 127933.63it/s]
# 🔍 Gesamtergebnis 2. Durchlauf (alle Goldstandard-Dateien)
# Precision: 0.290
# Recall:    0.144
# F1-Score:  0.193
#
# 📊 Metriken pro Kategorie:
# Label  Precision  Recall  F1-Score  Anzahl in Gold  Anzahl Predicted
#  DATE      0.445   0.252     0.322             290               164
# EVENT      0.169   0.114     0.136             237               160
#   LOC      0.373   0.069     0.117             403                75
#  TIME      0.500   0.324     0.393             213               138
# TOPIC      0.031   0.020     0.024             255               159

# %%
import json
from tqdm import tqdm
from collections import defaultdict
from sklearn.metrics import precision_recall_fscore_support
import pandas as pd

# === Dateien laden ===
with open("../../data/data_annotated.json", encoding="utf-8") as f:
    gold_data = json.load(f)

with open("../../data/NER/gemma2/prompt1/gemma2_prompt1_2_as_goldstructure.json", encoding="utf-8") as f:
    gemma_data = json.load(f)

# === Zu vergleichende Labels ===
label_names = ["LOC", "DATE", "TIME", "EVENT", "TOPIC"]

# === Entitäten extrahieren ===
def extract_entities(entry):
    ent_dict = {}
    for ent in entry.get("entities", []):
        label = ent.get("label")
        text = ent.get("text", "").strip()
        if label and text:
            ent_dict.setdefault(label, []).append(text)
    return ent_dict

# === Gemeinsame Dateien filtern ===
gold_files = {entry["file_name"] for entry in gold_data}
gemma_files = {entry["file_name"] for entry in gemma_data}
common_files = gold_files & gemma_files

filtered_gold = [entry for entry in gold_data if entry["file_name"] in common_files]
gemma_dict = {entry["file_name"]: entry for entry in gemma_data if entry["file_name"] in common_files}

# === Vergleich vorbereiten ===
y_true_all = []
y_pred_all = []

# pro Label getrennte Zählung
y_true_per_label = defaultdict(list)
y_pred_per_label = defaultdict(list)

# === Vergleichsloop ===
for gold_entry in tqdm(filtered_gold):
    file_name = gold_entry["file_name"]
    gold_ents = extract_entities(gold_entry)
    pred_entry = gemma_dict.get(file_name)
    pred_ents = extract_entities(pred_entry) if pred_entry else {}

    for label in label_names:
        gold_texts = set(t.strip() for t in gold_ents.get(label, []) if isinstance(t, str))
        val = pred_ents.get(label)

        if isinstance(val, list):
            pred_texts = set(t.strip() for t in val if isinstance(t, str))
        elif isinstance(val, str):
            pred_texts = {val.strip()}
        else:
            pred_texts = set()

        # True Positives und False Negatives
        for text in gold_texts:
            if text in pred_texts:
                y_true_all.append(1)
                y_pred_all.append(1)
                y_true_per_label[label].append(1)
                y_pred_per_label[label].append(1)
                pred_texts.remove(text)
            else:
                y_true_all.append(1)
                y_pred_all.append(0)
                y_true_per_label[label].append(1)
                y_pred_per_label[label].append(0)

        # Verbleibende Vorhersagen = False Positives
        for text in pred_texts:
            y_true_all.append(0)
            y_pred_all.append(1)
            y_true_per_label[label].append(0)
            y_pred_per_label[label].append(1)

# === Gesamtmetriken ===
precision, recall, f1, _ = precision_recall_fscore_support(
    y_true_all, y_pred_all, average="binary", zero_division=0
)

print("\n🔍 Gesamtergebnis (nur gemeinsame Dateien)")
print(f"Precision: {precision:.3f}")
print(f"Recall:    {recall:.3f}")
print(f"F1-Score:  {f1:.3f}")

# === Metriken pro Label ===
rows = []
for label in label_names:
    y_true = y_true_per_label[label]
    y_pred = y_pred_per_label[label]

    if not y_true and not y_pred:
        precision = recall = f1 = 0.0
    else:
        precision, recall, f1, _ = precision_recall_fscore_support(
            y_true, y_pred, average="binary", zero_division=0
        )

    rows.append({
        "Label": label,
        "Precision": round(precision, 3),
        "Recall": round(recall, 3),
        "F1-Score": round(f1, 3),
        "Anzahl in Gold": sum(y_true),
        "Anzahl Predicted": sum(y_pred)
    })

# Ausgabe als Tabelle
df_metrics = pd.DataFrame(rows).sort_values("Label")
print("\n📊 Metriken pro Kategorie:")
print(df_metrics.to_string(index=False))
# Out:
# 100%|██████████████████████████████████████| 160/160 [00:00<00:00, 98227.26it/s]
# 🔍 Gesamtergebnis (nur gemeinsame Dateien)
# Precision: 0.290
# Recall:    0.184
# F1-Score:  0.226
#
# 📊 Metriken pro Kategorie:
# Label  Precision  Recall  F1-Score  Anzahl in Gold  Anzahl Predicted
#  DATE      0.445   0.319     0.372             229               164
# EVENT      0.169   0.141     0.154             191               160
#   LOC      0.373   0.090     0.145             312                75
#  TIME      0.500   0.408     0.450             169               138
# TOPIC      0.031   0.026     0.028             194               159

# %% [markdown]
# ---
# ### Vergleich - Übereinstimmungen

# %%
import json

with open("../../data/NER/gemma2/prompt1/gemma2_prompt1_1_as_goldstructure.json", encoding="utf-8") as f:
    prompt1 = json.load(f)

with open("../../data/NER/gemma2/prompt1/gemma2_prompt1_2_as_goldstructure.json", encoding="utf-8") as f:
    prompt2 = json.load(f)

# Set der file_names extrahieren
file_names1 = {entry['file_name'] for entry in prompt1}
file_names2 = {entry['file_name'] for entry in prompt2}


gemeinsame = file_names1 & file_names2


print(f"Anzahl der Einträge 1. Durchlauf: {len(prompt1)}")
print(f"Anzahl der Einträge 2. Durchlauf: {len(prompt2)}")
print(f"Gemeinsame Einträge (file_name): {len(gemeinsame)}")
# Out:
# Anzahl der Einträge 1. Durchlauf: 160
# Anzahl der Einträge 2. Durchlauf: 160
# Gemeinsame Einträge (file_name): 128

# %%
---> es wurden bei unterschiedlichen Textfiles keine Entitäten extrahiert
