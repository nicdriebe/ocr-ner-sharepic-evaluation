# %% [markdown]
# # Datensatz - Überblick

# %% [markdown]
# Die Informationen zu den Bildern wurden in einer CSV-Datei zusammengestellt. Im Folgenden werden die Daten näher betrachtet.

# %%
import pandas as pd

file_path = ("data/image_data_with_groundtruth.csv")

df = pd.read_csv(file_path)
df.head()
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
#                                        original name file_name category  \
# 0  Weihnachtsfeier im Sprachcafé! Wir laden euch ...  0001.jpg    noisy
# 1  Dresden 8.8. 16 Uhr #demokratischerwiderstand ...  0002.jpg    noisy
# 2  kein vergeben – kein vergessen- gedenken heißt...  0003.jpg    noisy
# 3  Am Mittwoch singen wir wieder gemeinsam! Diesm...  0004.jpg    noisy
# 4  das ---amt blank empfiehlt-demo gegen gentrifi...  0006.jpg    noisy
#
#                                                  URL  Plattform  \
# 0  https://www.instagram.com/p/CXTzhTAs4O2/?img_i...  Instagram
# 1           https://www.instagram.com/p/CDbyO8SnQ9Z/  Instagram
# 2           https://www.instagram.com/p/CzRO0TuqUEN/  Instagram
# 3           https://www.instagram.com/p/Ctqhn4Ct99Z/  Instagram
# ...

# %%
df.shape
# Out:
# (200, 8)

# %% [markdown]
# NAN Werte nur bei Spalte URL, da Telegram Channel ohne URL

# %%
print(df.isna().sum())
# Out:
# original name     0
# file_name         0
# category          0
# URL              16
# Plattform         0
# channel name      0
# ground_truth      0
# OCR_ChatGPT4      0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ---

# %% [markdown]
# #### genutze Social Media Plattformen für die Bildsammlung

# %%
print(df['Plattform'].value_counts())
# Out:
# Plattform
# Instagram    184
# Telegram      16
# Name: count, dtype: int64

# %% [markdown]
# #### Anzahl der unterschiedlichen Social Media Channels

# %%
print(df['channel name'].value_counts())
# Out:
# channel name
# about.blank.berlin               40
# gerade.denken                    21
# nichtohneuns                     19
# demo.ticker.berlin               12
# Berlin Demos                     10
# omasgegenrechts                   8
# veranstaltungsforumffb            6
# antifanordost                     5
# konzerteundfestivals              4
# volksbuehne.berlin                4
# kulturzentrumbim                  4
# aufstehen_gegen_rassismus         4
# befreiung.und.widerstand          3
# kiez_kueche                       3
# dojosw                            3
# Konzerte Leipzig/Halle            3
# querdenken551                     3
# WORLD WIDE DEMO DEUTSCHLAND       3
# feminism.unlimited                3
# afd.bund                          2
# queermany.brlin                   2
# volksbuehne_berlin                2
# a100wegbassen                     2
# mehr_demokratie                   2
# smash.comedy.club                 2
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### Anzahl der Bilder pro Kategorie

# %%
print(df['category'].value_counts())
# Out:
# category
# simple    65
# fancy     54
# skewed    31
# noisy     30
# photo     20
# Name: count, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# #### Beispielbild pro Kategorie

# %%
from PIL import Image
from IPython.display import display

img = Image.open('data/images/insta_images/0123.jpg')
img_resized = img.resize((300, 300))
print("simple")
display(img_resized)
# Out:
# simple
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
from PIL import Image
from IPython.display import display

img = Image.open('data/images/insta_images/0238.jpg')
img_resized = img.resize((300, 300))
print("fancy")
display(img_resized)
# Out:
# fancy
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
from PIL import Image
from IPython.display import display

img = Image.open('data/images/insta_images/0229.jpg')
img_resized = img.resize((300, 300))
print("skewed")
display(img_resized)
# Out:
# skewed
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
from PIL import Image
from IPython.display import display

img = Image.open('data/images/insta_images/0001.jpg')
img_resized = img.resize((300, 300))
print("noisy")
display(img_resized)
# Out:
# noisy
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
from PIL import Image
from IPython.display import display

img = Image.open('data/images/insta_images/0104.jpg')
img_resized = img.resize((300, 380))
print("photo")
display(img_resized)
# Out:
# photo
# <PIL.Image.Image image mode=RGB size=300x380>
